# %%
import matplotlib.pyplot as plt
import networkx as nx
import csv

# Establish variables to be filled with public transport data
stops = {}
stopsOnTrip = {}
routes = {}

# Load metadata about each stop (hållplats) in Uppsala
with open('./gtfs_static_data_ul/stops.csv') as file:
    reader = csv.DictReader(file)
    # Create dictionary key for each row in stops.csv with values on name, latitude and longitude
    for row in reader:
        stops[row['stop_id']] = {'stop_id': row['stop_id'], 'stop_name': row['stop_name'],
                                 'stop_lat': row['stop_lat'], 'stop_lon': row['stop_lon']}

# Load data on when all trips (avgångar) pass each stop (hållplats) in Uppsala
with open('./gtfs_static_data_ul/stop_times.csv') as file:
    reader1 = csv.DictReader(file)
    # Loops through stop_times.csv and creates dictionary with stops per unique trip
    for row in reader1:
        if row['trip_id'] not in stopsOnTrip:
            stopsOnTrip[row['trip_id']] = [stops[row['stop_id']]]
        if row['trip_id'] in stopsOnTrip:
            stopsOnTrip[row['trip_id']].append(stops[row['stop_id']])

# Load data on all trips (avgångar) in Uppsala
with open('./gtfs_static_data_ul/trips.csv') as file:
    reader2 = csv.DictReader(file)
    # Loops through trips.csv and creates dictionary with the first trip per unique route
    for row in reader2:
        if row['route_id'] not in routes:
            routes[row['route_id']] = stopsOnTrip[row['trip_id']]

# %%
H = nx.Graph()

def createGraphFromRoute(id):
    for i,stop in enumerate(routes[id]):
        if i+1 < len(routes[id]):
            H.add_edge(routes[id][i]['stop_id'],routes[id][i+1]['stop_id'],weight=4.5)
    nx.draw(H)

# %%
import math

createGraphFromRoute('9011001059300000')
print(routes['9011001059300000'])
print(math.sqrt(4))
# Out:
# [{'stop_id': '9022003700600014', 'stop_name': 'Uppsala Centralstationen (Uppsala)', 'stop_lat': '59.857282', 'stop_lon': '17.648266'}, {'stop_id': '9022003700600014', 'stop_name': 'Uppsala Centralstationen (Uppsala)', 'stop_lat': '59.857282', 'stop_lon': '17.648266'}, {'stop_id': '9022003730059001', 'stop_name': 'Nova Park (Alsike) (Knivsta)', 'stop_lat': '59.740682', 'stop_lon': '17.814290'}, {'stop_id': '9022003780050001', 'stop_name': 'Knivsta station (Knivsta)', 'stop_lat': '59.727162', 'stop_lon': '17.786418'}, {'stop_id': '9022003730059002', 'stop_name': 'Nova Park (Alsike) (Knivsta)', 'stop_lat': '59.740507', 'stop_lon': '17.814013'}, {'stop_id': '9022003191170002', 'stop_name': 'Tomta (Arlanda) (Sigtuna)', 'stop_lat': '59.632036', 'stop_lon': '17.909001'}, {'stop_id': '9022003191074003', 'stop_name': 'Arlanda Gränsgatan', 'stop_lat': '59.635869', 'stop_lon': '17.929686'}, {'stop_id': '9022003191300001', 'stop_name': 'Brovägen (Arlanda) (Sigtuna)', 'stop_lat': '59.643548', 'stop_lon': '17.931200'}, {'stop_id': '9022003191159001', 'stop_name': 'Versailles (Arlanda) (Sigtuna)', 'stop_lat': '59.648991', 'stop_lon': '17.935553'}, {'stop_id': '9022003191042005', 'stop_name': 'Arlanda terminal 5', 'stop_lat': '59.651661', 'stop_lon': '17.934250'}, {'stop_id': '9022003191225005', 'stop_name': 'Arlanda terminal 4', 'stop_lat': '59.646866', 'stop_lon': '17.928731'}, {'stop_id': '9022003191086005', 'stop_name': 'Arlanda terminal 2 - 3', 'stop_lat': '59.644078', 'stop_lon': '17.930116'}, {'stop_id': '9022003191174001', 'stop_name': 'Järva krog (Solna)', 'stop_lat': '59.376462', 'stop_lon': '18.014276'}, {'stop_id': '9022003191301001', 'stop_name': 'Stockholm Cityterminalen (Kungsg.) (Stoc', 'stop_lat': '59.328706', 'stop_lon': '18.064193'}]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-d7029c3a96c9> in <module>
#       1 createGraphFromRoute('9011001059300000')
#       2 print(routes['9011001059300000'])
# ----> 3 print(sqrt(4))
#
# NameError: name 'sqrt' is not defined

# %%
print(H.nodes(data=True))
# Out:
# []

# %%
G.add_nodes_from([(key, {'attributes': values}) for (key, values) in stops.items()])
nx.draw_networkx(G)
